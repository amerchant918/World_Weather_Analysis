# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 616

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6b92f45b49ee20d49d94ae33601d90d6

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        try:
            city_rain = city_weather["rain"]["1h"]
        except:
            city_rain = 0
        pass
        try:
            city_snow = city_weather["snow"]["1h"]
        except:
            city_snow = 0
        pass
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_description,
                          "Country": city_country,
                          "Rain (inches)" : city_rain,
                          "Snow (inches)" : city_snow})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | mar del plata
# Processing Record 5 of Set 1 | beringovskiy
# Processing Record 6 of Set 1 | havelock
# Processing Record 7 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | southbridge
# Processing Record 11 of Set 1 | kieta
# Processing Record 12 of Set 1 | isangel
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | tateyama
# Processing Record 15 of Set 1 | dalbandin
# Processing Record 16 of Set 1 | victoria
# Processing Record 17 of Set 1 | beira
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | henties bay
# Processing Record 21 of Set 1 | tawnat
# City not found. Skipping...
# Processing Record 22 of Set 1 | paamiut
# Processing Record 23 of Set 1 | katsuura
# Processing Record 24 of Set 1 | clyde river
# Processing Record 25 of Set 1 | voskresenskoye
# Processing Record 26 of Set 1 | haines junction
# Processing Record 27 of Set 1 | linguere
# Processing Record 28 of Set 1 | anzhero-sudzhensk
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | barrow
# Processing Record 31 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 1 | kodiak
# Processing Record 33 of Set 1 | bambous virieux
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | santa fe
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | katangli
# Processing Record 39 of Set 1 | ancud
# Processing Record 40 of Set 1 | powell river
# Processing Record 41 of Set 1 | timmins
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | luderitz
# Processing Record 44 of Set 1 | karpogory
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | filadelfia
# Processing Record 48 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 1 | east london
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 1 of Set 2 | robore
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | tasiilaq
# Processing Record 5 of Set 2 | san quintin
# Processing Record 6 of Set 2 | pisco
# Processing Record 7 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 2 | maumere
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | upernavik
# Processing Record 11 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | tekax
# City not found. Skipping...
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | arraial do cabo
# Processing Record 16 of Set 2 | ponta do sol
# Processing Record 17 of Set 2 | pontianak
# Processing Record 18 of Set 2 | fortuna
# Processing Record 19 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 2 | kudahuvadhoo
# Processing Record 21 of Set 2 | hilo
# Processing Record 22 of Set 2 | falun
# Processing Record 23 of Set 2 | savannah bight
# Processing Record 24 of Set 2 | kavieng
# Processing Record 25 of Set 2 | presidencia roque saenz pena
# Processing Record 26 of Set 2 | alice springs
# Processing Record 27 of Set 2 | buraydah
# Processing Record 28 of Set 2 | sioux lookout
# Processing Record 29 of Set 2 | dikson
# Processing Record 30 of Set 2 | nuuk
# Processing Record 31 of Set 2 | thinadhoo
# Processing Record 32 of Set 2 | maceio
# Processing Record 33 of Set 2 | thompson
# Processing Record 34 of Set 2 | khatanga
# Processing Record 35 of Set 2 | kasempa
# Processing Record 36 of Set 2 | great bend
# Processing Record 37 of Set 2 | tomatlan
# Processing Record 38 of Set 2 | alyangula
# Processing Record 39 of Set 2 | beyla
# Processing Record 40 of Set 2 | wahiawa
# Processing Record 41 of Set 2 | puerto narino
# Processing Record 42 of Set 2 | saint anthony
# Processing Record 43 of Set 2 | geraldton
# Processing Record 44 of Set 2 | batemans bay
# Processing Record 45 of Set 2 | albany
# Processing Record 46 of Set 2 | nikolskoye
# Processing Record 47 of Set 2 | chuy
# Processing Record 48 of Set 2 | sabinas
# Processing Record 49 of Set 2 | iisalmi
# Processing Record 50 of Set 2 | ugoofaaru
# Processing Record 1 of Set 3 | yatou
# Processing Record 2 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 3 | havoysund
# Processing Record 4 of Set 3 | zhigansk
# Processing Record 5 of Set 3 | dmitriyevskoye
# Processing Record 6 of Set 3 | hasaki
# Processing Record 7 of Set 3 | saint-pierre
# Processing Record 8 of Set 3 | ust-kuyga
# Processing Record 9 of Set 3 | curvelo
# Processing Record 10 of Set 3 | chichihualco
# Processing Record 11 of Set 3 | atuona
# Processing Record 12 of Set 3 | qaanaaq
# Processing Record 13 of Set 3 | lima
# Processing Record 14 of Set 3 | taoudenni
# Processing Record 15 of Set 3 | tuktoyaktuk
# Processing Record 16 of Set 3 | yellowknife
# Processing Record 17 of Set 3 | hambantota
# Processing Record 18 of Set 3 | otane
# Processing Record 19 of Set 3 | touros
# Processing Record 20 of Set 3 | ngunguru
# Processing Record 21 of Set 3 | solnechnyy
# Processing Record 22 of Set 3 | norman wells
# Processing Record 23 of Set 3 | chokurdakh
# Processing Record 24 of Set 3 | sept-iles
# Processing Record 25 of Set 3 | talnakh
# Processing Record 26 of Set 3 | ouidah
# Processing Record 27 of Set 3 | saint-augustin
# Processing Record 28 of Set 3 | bardiyah
# Processing Record 29 of Set 3 | champerico
# Processing Record 30 of Set 3 | hami
# Processing Record 31 of Set 3 | sola
# Processing Record 32 of Set 3 | olafsvik
# Processing Record 33 of Set 3 | atherton
# Processing Record 34 of Set 3 | ulaanbaatar
# Processing Record 35 of Set 3 | bonthe
# Processing Record 36 of Set 3 | banda aceh
# Processing Record 37 of Set 3 | avera
# Processing Record 38 of Set 3 | pemba
# Processing Record 39 of Set 3 | aswan
# Processing Record 40 of Set 3 | marawi
# Processing Record 41 of Set 3 | kem
# Processing Record 42 of Set 3 | lebu
# Processing Record 43 of Set 3 | portland
# Processing Record 44 of Set 3 | hobart
# Processing Record 45 of Set 3 | shawinigan
# Processing Record 46 of Set 3 | saint george
# Processing Record 47 of Set 3 | gimli
# Processing Record 48 of Set 3 | oranjemund
# Processing Record 49 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 50 of Set 3 | leningradskiy
# Processing Record 1 of Set 4 | takaka
# Processing Record 2 of Set 4 | kerchevskiy
# Processing Record 3 of Set 4 | jining
# Processing Record 4 of Set 4 | obluche
# City not found. Skipping...
# Processing Record 5 of Set 4 | hofn
# Processing Record 6 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 4 | usak
# Processing Record 8 of Set 4 | mednogorsk
# Processing Record 9 of Set 4 | mahebourg
# Processing Record 10 of Set 4 | phayakkhaphum phisai
# Processing Record 11 of Set 4 | severo-kurilsk
# Processing Record 12 of Set 4 | caravelas
# Processing Record 13 of Set 4 | esperance
# Processing Record 14 of Set 4 | longyearbyen
# Processing Record 15 of Set 4 | afgoye
# City not found. Skipping...
# Processing Record 16 of Set 4 | gambela
# Processing Record 17 of Set 4 | flinders
# Processing Record 18 of Set 4 | teahupoo
# Processing Record 19 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 20 of Set 4 | villa carlos paz
# Processing Record 21 of Set 4 | coihueco
# Processing Record 22 of Set 4 | nome
# Processing Record 23 of Set 4 | kaitangata
# Processing Record 24 of Set 4 | ostrovnoy
# Processing Record 25 of Set 4 | bluff
# Processing Record 26 of Set 4 | marsh harbour
# Processing Record 27 of Set 4 | anloga
# Processing Record 28 of Set 4 | bethel
# Processing Record 29 of Set 4 | hokitika
# Processing Record 30 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 4 | turochak
# Processing Record 32 of Set 4 | praia da vitoria
# Processing Record 33 of Set 4 | hanchuan
# Processing Record 34 of Set 4 | dingle
# Processing Record 35 of Set 4 | vardo
# Processing Record 36 of Set 4 | tuatapere
# Processing Record 37 of Set 4 | nishihara
# Processing Record 38 of Set 4 | kolaras
# Processing Record 39 of Set 4 | port hedland
# Processing Record 40 of Set 4 | colares
# Processing Record 41 of Set 4 | vila franca do campo
# Processing Record 42 of Set 4 | atasu
# Processing Record 43 of Set 4 | guerrero negro
# Processing Record 44 of Set 4 | lata
# Processing Record 45 of Set 4 | chernyshevskiy
# Processing Record 46 of Set 4 | bilibino
# Processing Record 47 of Set 4 | rio gallegos
# Processing Record 48 of Set 4 | ranong
# Processing Record 49 of Set 4 | saldanha
# Processing Record 50 of Set 4 | umm lajj
# Processing Record 1 of Set 5 | san patricio
# Processing Record 2 of Set 5 | orlik
# Processing Record 3 of Set 5 | orange cove
# Processing Record 4 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 5 | sur
# Processing Record 6 of Set 5 | mahibadhoo
# Processing Record 7 of Set 5 | faanui
# Processing Record 8 of Set 5 | oistins
# Processing Record 9 of Set 5 | fenoarivo atsinanana
# Processing Record 10 of Set 5 | mareeba
# Processing Record 11 of Set 5 | arlit
# Processing Record 12 of Set 5 | tartus
# Processing Record 13 of Set 5 | golden
# Processing Record 14 of Set 5 | lasa
# Processing Record 15 of Set 5 | tarragona
# Processing Record 16 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 5 | saskylakh
# Processing Record 18 of Set 5 | segovia
# Processing Record 19 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 5 | kasongo-lunda
# Processing Record 21 of Set 5 | vallenar
# Processing Record 22 of Set 5 | ilo
# Processing Record 23 of Set 5 | bereda
# Processing Record 24 of Set 5 | fort-shevchenko
# Processing Record 25 of Set 5 | ciras
# City not found. Skipping...
# Processing Record 26 of Set 5 | kahului
# Processing Record 27 of Set 5 | lannion
# Processing Record 28 of Set 5 | mapiri
# Processing Record 29 of Set 5 | skofja loka
# Processing Record 30 of Set 5 | maarianhamina
# Processing Record 31 of Set 5 | fukuma
# Processing Record 32 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 33 of Set 5 | la ronge
# Processing Record 34 of Set 5 | charters towers
# Processing Record 35 of Set 5 | malakal
# Processing Record 36 of Set 5 | nouadhibou
# Processing Record 37 of Set 5 | santiago
# Processing Record 38 of Set 5 | kangaatsiaq
# Processing Record 39 of Set 5 | castro
# Processing Record 40 of Set 5 | gombong
# Processing Record 41 of Set 5 | dawei
# Processing Record 42 of Set 5 | kavaratti
# Processing Record 43 of Set 5 | pochutla
# Processing Record 44 of Set 5 | asuncion nochixtlan
# Processing Record 45 of Set 5 | zatoka
# Processing Record 46 of Set 5 | pangoa
# Processing Record 47 of Set 5 | lompoc
# Processing Record 48 of Set 5 | chicama
# Processing Record 49 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 50 of Set 5 | sao filipe
# Processing Record 1 of Set 6 | bandarbeyla
# Processing Record 2 of Set 6 | silchar
# Processing Record 3 of Set 6 | westport
# Processing Record 4 of Set 6 | almaznyy
# Processing Record 5 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 6 | sovetskiy
# Processing Record 7 of Set 6 | itarema
# Processing Record 8 of Set 6 | srednekolymsk
# Processing Record 9 of Set 6 | barra do garcas
# Processing Record 10 of Set 6 | inta
# Processing Record 11 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 6 | hithadhoo
# Processing Record 13 of Set 6 | casa grande
# Processing Record 14 of Set 6 | severnoye
# Processing Record 15 of Set 6 | akropong
# Processing Record 16 of Set 6 | halifax
# Processing Record 17 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 6 | kalmunai
# Processing Record 19 of Set 6 | carnarvon
# Processing Record 20 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 6 | kruisfontein
# Processing Record 22 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 23 of Set 6 | gat
# Processing Record 24 of Set 6 | san francisco
# Processing Record 25 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 26 of Set 6 | mount gambier
# Processing Record 27 of Set 6 | los llanos de aridane
# Processing Record 28 of Set 6 | bathsheba
# Processing Record 29 of Set 6 | harindanga
# Processing Record 30 of Set 6 | poum
# Processing Record 31 of Set 6 | basco
# Processing Record 32 of Set 6 | port said
# Processing Record 33 of Set 6 | naze
# Processing Record 34 of Set 6 | pompeia
# Processing Record 35 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 6 | harbour breton
# Processing Record 37 of Set 6 | port elizabeth
# Processing Record 38 of Set 6 | tekirdag
# Processing Record 39 of Set 6 | port hardy
# Processing Record 40 of Set 6 | north shore
# Processing Record 41 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 43 of Set 6 | russell
# Processing Record 44 of Set 6 | fairbanks
# Processing Record 45 of Set 6 | kurilsk
# Processing Record 46 of Set 6 | sinnamary
# Processing Record 47 of Set 6 | santa marta
# Processing Record 48 of Set 6 | fomboni
# Processing Record 49 of Set 6 | vestmannaeyjar
# Processing Record 50 of Set 6 | alihe
# Processing Record 1 of Set 7 | bitung
# Processing Record 2 of Set 7 | iracoubo
# Processing Record 3 of Set 7 | margate
# Processing Record 4 of Set 7 | lalas
# Processing Record 5 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 6 of Set 7 | bahia blanca
# Processing Record 7 of Set 7 | esmeraldas
# Processing Record 8 of Set 7 | denpasar
# Processing Record 9 of Set 7 | la rioja
# Processing Record 10 of Set 7 | lagoa
# Processing Record 11 of Set 7 | lichtenburg
# Processing Record 12 of Set 7 | jumla
# Processing Record 13 of Set 7 | shimoda
# Processing Record 14 of Set 7 | springdale
# Processing Record 15 of Set 7 | djenne
# Processing Record 16 of Set 7 | devarkonda
# Processing Record 17 of Set 7 | ramnagar
# Processing Record 18 of Set 7 | goderich
# Processing Record 19 of Set 7 | huilong
# Processing Record 20 of Set 7 | college
# Processing Record 21 of Set 7 | hakkari
# Processing Record 22 of Set 7 | provideniya
# Processing Record 23 of Set 7 | bengkulu
# Processing Record 24 of Set 7 | ilulissat
# Processing Record 25 of Set 7 | seydi
# Processing Record 26 of Set 7 | rocha
# Processing Record 27 of Set 7 | mineiros
# Processing Record 28 of Set 7 | melykut
# Processing Record 29 of Set 7 | hay river
# Processing Record 30 of Set 7 | rabat
# Processing Record 31 of Set 7 | kulhudhuffushi
# Processing Record 32 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 7 | cabo san lucas
# Processing Record 34 of Set 7 | nara
# Processing Record 35 of Set 7 | kholodnyy
# Processing Record 36 of Set 7 | humberto de campos
# Processing Record 37 of Set 7 | yar-sale
# Processing Record 38 of Set 7 | cherskiy
# Processing Record 39 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 7 | cobija
# Processing Record 41 of Set 7 | constitucion
# Processing Record 42 of Set 7 | vung tau
# Processing Record 43 of Set 7 | usinsk
# Processing Record 44 of Set 7 | vao
# Processing Record 45 of Set 7 | evensk
# Processing Record 46 of Set 7 | biak
# Processing Record 47 of Set 7 | baker city
# Processing Record 48 of Set 7 | del rio
# Processing Record 49 of Set 7 | staryy nadym
# Processing Record 50 of Set 7 | namwala
# Processing Record 1 of Set 8 | porto santo
# Processing Record 2 of Set 8 | carauari
# Processing Record 3 of Set 8 | dunedin
# Processing Record 4 of Set 8 | narsaq
# Processing Record 5 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 8 | ahualulco
# Processing Record 7 of Set 8 | codrington
# Processing Record 8 of Set 8 | plettenberg bay
# Processing Record 9 of Set 8 | corsicana
# Processing Record 10 of Set 8 | calama
# Processing Record 11 of Set 8 | hayrabolu
# Processing Record 12 of Set 8 | qaqortoq
# Processing Record 13 of Set 8 | odweyne
# Processing Record 14 of Set 8 | yumen
# Processing Record 15 of Set 8 | silivainiotika
# City not found. Skipping...
# Processing Record 16 of Set 8 | zhigalovo
# Processing Record 17 of Set 8 | kijang
# Processing Record 18 of Set 8 | klaksvik
# Processing Record 19 of Set 8 | bertoua
# Processing Record 20 of Set 8 | tautira
# Processing Record 21 of Set 8 | maizuru
# Processing Record 22 of Set 8 | berlevag
# Processing Record 23 of Set 8 | samfya
# Processing Record 24 of Set 8 | chisindia
# Processing Record 25 of Set 8 | chinhoyi
# Processing Record 26 of Set 8 | kousseri
# Processing Record 27 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 28 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 29 of Set 8 | pasni
# Processing Record 30 of Set 8 | nemuro
# Processing Record 31 of Set 8 | kibala
# Processing Record 32 of Set 8 | orcopampa
# Processing Record 33 of Set 8 | rockport
# Processing Record 34 of Set 8 | santa maria
# Processing Record 35 of Set 8 | myrtle beach
# Processing Record 36 of Set 8 | shar
# Processing Record 37 of Set 8 | noumea
# Processing Record 38 of Set 8 | mpongwe
# Processing Record 39 of Set 8 | balkanabat
# Processing Record 40 of Set 8 | demba
# Processing Record 41 of Set 8 | ho
# City not found. Skipping...
# Processing Record 42 of Set 8 | urumqi
# Processing Record 43 of Set 8 | santa isabel do rio negro
# Processing Record 44 of Set 8 | molina
# Processing Record 45 of Set 8 | miles city
# Processing Record 46 of Set 8 | mecca
# Processing Record 47 of Set 8 | kayerkan
# Processing Record 48 of Set 8 | caraycaray
# Processing Record 49 of Set 8 | byron bay
# Processing Record 50 of Set 8 | bahir dar
# Processing Record 1 of Set 9 | cidreira
# Processing Record 2 of Set 9 | honningsvag
# Processing Record 3 of Set 9 | tura
# Processing Record 4 of Set 9 | ambon
# Processing Record 5 of Set 9 | kolpashevo
# Processing Record 6 of Set 9 | nanortalik
# Processing Record 7 of Set 9 | ksenyevka
# City not found. Skipping...
# Processing Record 8 of Set 9 | port hawkesbury
# Processing Record 9 of Set 9 | la palma
# Processing Record 10 of Set 9 | egvekinot
# Processing Record 11 of Set 9 | labytnangi
# Processing Record 12 of Set 9 | catamarca
# Processing Record 13 of Set 9 | muros
# Processing Record 14 of Set 9 | tartki
# City not found. Skipping...
# Processing Record 15 of Set 9 | karratha
# Processing Record 16 of Set 9 | mabaruma
# Processing Record 17 of Set 9 | gamba
# Processing Record 18 of Set 9 | sembe
# Processing Record 19 of Set 9 | krasnoselkup
# Processing Record 20 of Set 9 | cururupu
# Processing Record 21 of Set 9 | murdochville
# Processing Record 22 of Set 9 | faya
# Processing Record 23 of Set 9 | lumberton
# Processing Record 24 of Set 9 | araouane
# Processing Record 25 of Set 9 | ereymentau
# Processing Record 26 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 27 of Set 9 | namatanai
# Processing Record 28 of Set 9 | horsham
# Processing Record 29 of Set 9 | burica
# City not found. Skipping...
# Processing Record 30 of Set 9 | sistranda
# Processing Record 31 of Set 9 | san buenaventura
# Processing Record 32 of Set 9 | roald
# Processing Record 33 of Set 9 | deputatskiy
# Processing Record 34 of Set 9 | kalmar
# Processing Record 35 of Set 9 | lazaro cardenas
# Processing Record 36 of Set 9 | marzuq
# Processing Record 37 of Set 9 | tirlyanskiy
# Processing Record 38 of Set 9 | erzin
# Processing Record 39 of Set 9 | campobello di mazara
# Processing Record 40 of Set 9 | dekoa
# City not found. Skipping...
# Processing Record 41 of Set 9 | iqaluit
# Processing Record 42 of Set 9 | cockburn town
# Processing Record 43 of Set 9 | torbay
# Processing Record 44 of Set 9 | kloulklubed
# Processing Record 45 of Set 9 | mega
# Processing Record 46 of Set 9 | gushikawa
# Processing Record 47 of Set 9 | dekar
# Processing Record 48 of Set 9 | camacha
# Processing Record 49 of Set 9 | high prairie
# Processing Record 50 of Set 9 | buta
# Processing Record 1 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 10 | tabou
# Processing Record 3 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 4 of Set 10 | kutum
# Processing Record 5 of Set 10 | asau
# Processing Record 6 of Set 10 | daryapur
# Processing Record 7 of Set 10 | port lincoln
# Processing Record 8 of Set 10 | himora
# City not found. Skipping...
# Processing Record 9 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 10 | ambatofinandrahana
# Processing Record 11 of Set 10 | alofi
# Processing Record 12 of Set 10 | tres picos
# Processing Record 13 of Set 10 | kendari
# Processing Record 14 of Set 10 | namibe
# Processing Record 15 of Set 10 | souillac
# Processing Record 16 of Set 10 | bucerias
# Processing Record 17 of Set 10 | ewa beach
# Processing Record 18 of Set 10 | seddon
# Processing Record 19 of Set 10 | vrangel
# Processing Record 20 of Set 10 | ibra
# Processing Record 21 of Set 10 | worland
# Processing Record 22 of Set 10 | gilgit
# Processing Record 23 of Set 10 | lalmohan
# Processing Record 24 of Set 10 | varhaug
# Processing Record 25 of Set 10 | sao joao da barra
# Processing Record 26 of Set 10 | porto novo
# Processing Record 27 of Set 10 | atyrau
# Processing Record 28 of Set 10 | one hundred mile house
# City not found. Skipping...
# Processing Record 29 of Set 10 | mumbwa
# Processing Record 30 of Set 10 | dauphin
# Processing Record 31 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 33 of Set 10 | pokrovsk
# Processing Record 34 of Set 10 | tungkang
# City not found. Skipping...
# Processing Record 35 of Set 10 | arkhara
# Processing Record 36 of Set 10 | belomorsk
# Processing Record 37 of Set 10 | pevek
# Processing Record 38 of Set 10 | macheng
# Processing Record 39 of Set 10 | cayenne
# Processing Record 40 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 41 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 42 of Set 10 | naifaru
# Processing Record 43 of Set 10 | teya
# Processing Record 44 of Set 10 | san carlos de bariloche
# Processing Record 45 of Set 10 | sao miguel
# Processing Record 46 of Set 10 | jalu
# Processing Record 47 of Set 10 | dunda
# Processing Record 48 of Set 10 | baruun-urt
# Processing Record 49 of Set 10 | totskoye
# Processing Record 50 of Set 10 | yumbe
# Processing Record 1 of Set 11 | banff
# Processing Record 2 of Set 11 | kattivakkam
# Processing Record 3 of Set 11 | zhob
# Processing Record 4 of Set 11 | gucheng
# Processing Record 5 of Set 11 | lavrentiya
# Processing Record 6 of Set 11 | asaka
# Processing Record 7 of Set 11 | mitsamiouli
# Processing Record 8 of Set 11 | kuytun
# Processing Record 9 of Set 11 | bulungu
# Processing Record 10 of Set 11 | sitka
# Processing Record 11 of Set 11 | seoul
# Processing Record 12 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 11 | poquoson
# Processing Record 14 of Set 11 | zhoucheng
# Processing Record 15 of Set 11 | katobu
# Processing Record 16 of Set 11 | saint-francois
# Processing Record 17 of Set 11 | chik
# Processing Record 18 of Set 11 | san andres
# Processing Record 19 of Set 11 | carmen
# Processing Record 20 of Set 11 | miri
# Processing Record 21 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 22 of Set 11 | nombre de dios
# Processing Record 23 of Set 11 | makakilo city
# Processing Record 24 of Set 11 | requena
# Processing Record 25 of Set 11 | kasba
# Processing Record 26 of Set 11 | hirara
# Processing Record 27 of Set 11 | whithorn
# Processing Record 28 of Set 11 | luanda
# Processing Record 29 of Set 11 | baglung
# Processing Record 30 of Set 11 | nicoya
# Processing Record 31 of Set 11 | maniitsoq
# Processing Record 32 of Set 11 | pangnirtung
# Processing Record 33 of Set 11 | paulista
# Processing Record 34 of Set 11 | lumby
# Processing Record 35 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 11 | orotina
# Processing Record 37 of Set 11 | lamar
# Processing Record 38 of Set 11 | ilhabela
# Processing Record 39 of Set 11 | nitra
# Processing Record 40 of Set 11 | aklavik
# Processing Record 41 of Set 11 | jeremie
# Processing Record 42 of Set 11 | mackay
# Processing Record 43 of Set 11 | grimshaw
# Processing Record 44 of Set 11 | port-gentil
# Processing Record 45 of Set 11 | tokat
# Processing Record 46 of Set 11 | srandakan
# Processing Record 47 of Set 11 | nueve de julio
# Processing Record 48 of Set 11 | hammerfest
# Processing Record 49 of Set 11 | galle
# Processing Record 50 of Set 11 | shenjiamen
# Processing Record 1 of Set 12 | bakchar
# Processing Record 2 of Set 12 | roma
# Processing Record 3 of Set 12 | biltine
# Processing Record 4 of Set 12 | komsomolskiy
# Processing Record 5 of Set 12 | lokosovo
# Processing Record 6 of Set 12 | moose factory
# Processing Record 7 of Set 12 | segezha
# Processing Record 8 of Set 12 | puerto escondido
# Processing Record 9 of Set 12 | chapais
# Processing Record 10 of Set 12 | nipawin
# Processing Record 11 of Set 12 | batsfjord
# Processing Record 12 of Set 12 | hamilton
# Processing Record 13 of Set 12 | anupgarh
# Processing Record 14 of Set 12 | matara
# Processing Record 15 of Set 12 | nacozari
# Processing Record 16 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 17 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 12 | bahia honda
# Processing Record 19 of Set 12 | yulara
# Processing Record 20 of Set 12 | asfi
# Processing Record 21 of Set 12 | shaunavon
# Processing Record 22 of Set 12 | airai
# Processing Record 23 of Set 12 | macouria
# Processing Record 24 of Set 12 | manta
# Processing Record 25 of Set 12 | sambava
# Processing Record 26 of Set 12 | samarai
# Processing Record 27 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 12 | mount isa
# Processing Record 29 of Set 12 | timra
# Processing Record 30 of Set 12 | brindisi
# Processing Record 31 of Set 12 | marmora
# Processing Record 32 of Set 12 | xingcheng
# Processing Record 33 of Set 12 | irricana
# Processing Record 34 of Set 12 | tevriz
# Processing Record 35 of Set 12 | havre-saint-pierre
# Processing Record 36 of Set 12 | starup
# Processing Record 37 of Set 12 | santa cruz
# Processing Record 38 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 39 of Set 12 | knokke-heist
# Processing Record 40 of Set 12 | kerema
# Processing Record 41 of Set 12 | moorhead
# Processing Record 42 of Set 12 | kambove
# Processing Record 43 of Set 12 | kenai
# Processing Record 44 of Set 12 | santa cruz del sur
# Processing Record 45 of Set 12 | cap malheureux
# Processing Record 46 of Set 12 | loudeac
# Processing Record 47 of Set 12 | dubenskiy
# City not found. Skipping...
# Processing Record 48 of Set 12 | agva
# City not found. Skipping...
# Processing Record 49 of Set 12 | richards bay
# Processing Record 50 of Set 12 | ratangarh
# Processing Record 1 of Set 13 | penalva
# Processing Record 2 of Set 13 | klyuchevsk
# Processing Record 3 of Set 13 | gaoua
# Processing Record 4 of Set 13 | nelson bay
# Processing Record 5 of Set 13 | boa vista
# Processing Record 6 of Set 13 | palmer
# Processing Record 7 of Set 13 | lyndon
# Processing Record 8 of Set 13 | marrakesh
# Processing Record 9 of Set 13 | upata
# Processing Record 10 of Set 13 | kupang
# Processing Record 11 of Set 13 | itacare
# Processing Record 12 of Set 13 | isla vista
# Processing Record 13 of Set 13 | puerto ayacucho
# Processing Record 14 of Set 13 | the valley
# Processing Record 15 of Set 13 | aykhal
# Processing Record 16 of Set 13 | kyren
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 553

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_df = pd.DataFrame(city_data)
city_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Busselton -33.65  115.33     43.00        84           2        8.19
# 1        Hermanus -34.42   19.23     54.00        87         100        4.00
# 2    Punta Arenas -53.15  -70.92     35.60        74          75       23.04
# 3   Mar Del Plata -38.00  -57.56     50.00        53           1       11.41
# 4    Beringovskiy  63.05  179.32     53.67        74          96        2.71
# 5        Havelock  34.88  -76.90     84.00        88          90       14.99
# 6           Vaini -21.20 -175.20     71.60        88          75        5.82
# 7  Ribeira Grande  38.52  -28.70     73.40        56          75        4.70
# 8     Southbridge  42.08  -72.03     87.01        61          27        5.48
# 9           Kieta  -6.22  155.63     80.04        79         100        8.16
#
#   Current Description Country  Rain(inches)  Snow(inches)
# 0           clear sky      AU          0.00             0
# 1       moderate rain      ZA          3.09             0
# 2       broken clouds      CL          0.00             0
# 3           clear sky      AR          0.00             0
# 4     overcast clouds      RU          0.00             0
# 5          light rain      US          0.25             0
# 6       broken clouds      TO          0.00             0
# 7       broken clouds      PT          0.00             0
# 8          light rain      US          0.19             0
# 9       moderate rain      PG          1.21             0

# %%
#Reordering the columns of the data frame
reordering_columns = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description","Rain (inches)","Snow (inches)"]

# %%
city_df = city_df[reordering_columns]
city_df
# Out:
#                 City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Busselton      AU -33.65  115.33     43.00        84           2
# 1           Hermanus      ZA -34.42   19.23     54.00        87         100
# 2       Punta Arenas      CL -53.15  -70.92     35.60        74          75
# 3      Mar Del Plata      AR -38.00  -57.56     50.00        53           1
# 4       Beringovskiy      RU  63.05  179.32     53.67        74          96
# ..               ...     ...    ...     ...       ...       ...         ...
# 548       Isla Vista      US  34.41 -119.86     62.60        82          90
# 549  Puerto Ayacucho      VE   5.66  -67.62     87.80        58          20
# 550       The Valley      AI  18.22  -63.06     89.60        62          75
# 551           Aykhal      RU  66.00  111.50     62.60        48          90
# 552            Kyren      RU  51.68  102.14     57.06        69          95
#
#      Wind Speed Current Description  Rain(inches)  Snow(inches)
# 0          8.19           clear sky          0.00             0
# 1          4.00       moderate rain          3.09             0
# 2         23.04       broken clouds          0.00             0
# 3         11.41           clear sky          0.00             0
# 4          2.71     overcast clouds          0.00             0
# ..          ...                 ...           ...           ...
# 548        5.82     overcast clouds          0.00             0
# 549        5.82          few clouds          0.00             0
# 550       17.22                haze          0.00             0
# 551       13.42     overcast clouds          0.00             0
# 552        1.70     overcast clouds          0.00             0
#
# [553 rows x 11 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_df.to_csv(output_data_file, index_label="City_ID")
